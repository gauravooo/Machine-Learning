# %%
from sklearn.linear_model import Ridge, Lasso
from sklearn.metrics import r2_score

# 1. Instantiate Ridge (L2)
ridge_model = Ridge(alpha=10.0) 
ridge_model.fit(X_train, y_train)

# 2. Instantiate Lasso (L1)
lasso_model = Lasso(alpha=0.1)
lasso_model.fit(X_train, y_train)

# Check the weights to see Lasso's feature selection in action!
print("Ridge Coefficients:", ridge_model.coef_)
print("Lasso Coefficients:", lasso_model.coef_) # You will see actual 0.0s here
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       4 # 1. Instantiate Ridge (L2)
#       5 ridge_model = Ridge(alpha=10.0)
# ----> 6 ridge_model.fit(X_train, y_train)
#       8 # 2. Instantiate Lasso (L1)
#       9 lasso_model = Lasso(alpha=0.1)
#
# NameError: name 'X_train' is not defined
