# %% [markdown]
# First Model(Basic model)

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

X = np.array([[1],[2],[3],[4],[5]])
y = np.array([40000 , 50000 , 65000 , 82000 , 96000])

model = LinearRegression()

model.fit(X,y)

print(f"Slope (Coefficient): {model.coef_}")
print(f"Intercept: {model.intercept_}")

prediction = model.predict([[6]])
print(f"Prediction for 6th year = {prediction}")
# Out:
# Slope (Coefficient): [14400.]
# Intercept: 23399.999999999993
# Prediction for 6th year = [109800.]
